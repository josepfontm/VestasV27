# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Chnage paths if necessary
file_PSD_u = '/run/media/jfont/Nuevo vol/V27 SHM/results_font/psd_sum/df_psd_u.csv'
file_PSD_15 = '/run/media/jfont/Nuevo vol/V27 SHM/results_font/psd_sum/df_psd_15.csv'
file_PSD_30 = '/run/media/jfont/Nuevo vol/V27 SHM/results_font/psd_sum/df_psd_30.csv'
file_PSD_45 = '/run/media/jfont/Nuevo vol/V27 SHM/results_font/psd_sum/df_psd_45.csv'
file_PSD_r = '/run/media/jfont/Nuevo vol/V27 SHM/results_font/psd_sum/df_psd_r.csv'

file_metadata = '/run/media/jfont/Nuevo vol/V27 SHM/results_font/metadata.csv'

psd_u = pd.read_csv(file_PSD_u, index_col = None, header = None)
psd_15 = pd.read_csv(file_PSD_15, index_col = None, header = None)
psd_30 = pd.read_csv(file_PSD_30, index_col = None, header = None)
psd_45 = pd.read_csv(file_PSD_45, index_col = None, header = None)
psd_r = pd.read_csv(file_PSD_r, index_col = None, header = None)

psd_u = psd_u.to_numpy()
psd_15 = psd_15.to_numpy()
psd_30 = psd_30.to_numpy()
psd_45 = psd_45.to_numpy()
psd_r = psd_r.to_numpy()

print(np.shape(psd_u))
# Out:
# (3064, 513)

# %%
plt.figure()
for i in range(np.shape(psd_u)[0]):
    plt.semilogy(psd_u[i,:],color='green',linewidth=0.01)

for i in range(np.shape(psd_15)[0]):
    plt.semilogy(psd_15[i,:],color='orange',linewidth=0.01)

for i in range(np.shape(psd_15)[0]):
    plt.semilogy(psd_15[i,:],color='blue',linewidth=0.01)

# for i in range(np.shape(psd_15)[0]):
#     plt.semilogy(psd_15[i,:],color='red',linewidth=0.01)

# for i in range(np.shape(psd_15)[0]):
#     plt.semilogy(psd_15[i,:],color='yellow',linewidth=0.01)

plt.show()
